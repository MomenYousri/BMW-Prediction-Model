# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt 
import seaborn as sns 
import warnings 
warnings.filterwarnings ('ignore')

# %%
df=pd.read_csv('BMW_Car_Sales_Classification.csv')

# %% [markdown]
# ### Explore data

# %%
df.head()
# Out:
#       Model  Year         Region  Color Fuel_Type Transmission  Engine_Size_L  \
# 0  5 Series  2016           Asia    Red    Petrol       Manual            3.5
# 1        i8  2013  North America    Red    Hybrid    Automatic            1.6
# 2  5 Series  2022  North America   Blue    Petrol    Automatic            4.5
# 3        X3  2024    Middle East   Blue    Petrol    Automatic            1.7
# 4  7 Series  2020  South America  Black    Diesel       Manual            2.1
#
#    Mileage_KM  Price_USD  Sales_Volume Sales_Classification
# 0      151748      98740          8300                 High
# 1      121671      79219          3428                  Low
# 2       10991     113265          6994                  Low
# 3       27255      60971          4047                  Low
# 4      122131      49898          3080                  Low

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50000 entries, 0 to 49999
# Data columns (total 11 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Model                 50000 non-null  object
#  1   Year                  50000 non-null  int64
#  2   Region                50000 non-null  object
#  3   Color                 50000 non-null  object
#  4   Fuel_Type             50000 non-null  object
#  5   Transmission          50000 non-null  object
#  6   Engine_Size_L         50000 non-null  float64
#  7   Mileage_KM            50000 non-null  int64
#  8   Price_USD             50000 non-null  int64
#  9   Sales_Volume          50000 non-null  int64
#  10  Sales_Classification  50000 non-null  object
# dtypes: float64(1), int64(4), object(6)
# memory usage: 4.2+ MB

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.isna().sum()
# Out:
# Model                   0
# Year                    0
# Region                  0
# Color                   0
# Fuel_Type               0
# Transmission            0
# Engine_Size_L           0
# Mileage_KM              0
# Price_USD               0
# Sales_Volume            0
# Sales_Classification    0
# dtype: int64

# %%
sns.heatmap(df.isna())
plt.show()

# %% [markdown]
# ### feature engineering to add column Total price Because the price_USD is for one car only

# %%
df['Total price']=df['Price_USD']*df['Sales_Volume']

# %%
df.sample(5)
# Out:
#           Model  Year       Region  Color Fuel_Type Transmission  \
# 11969  5 Series  2016       Europe   Grey    Hybrid    Automatic
# 32116        X6  2014       Africa  Black  Electric    Automatic
# 36683  7 Series  2017         Asia   Grey    Hybrid    Automatic
# 45217        X5  2024  Middle East   Blue    Diesel    Automatic
# 40343  5 Series  2020       Africa    Red  Electric    Automatic
#
#        Engine_Size_L  Mileage_KM  Price_USD  Sales_Volume  \
# 11969            2.5       82613      64936          1810
# 32116            2.7      136054     105845          6656
# 36683            5.0      142681      44839          3208
# 45217            2.6      143834     117626          8007
# 40343            3.2      152484     105927          6497
#
#       Sales_Classification  Total price
# 11969                  Low    117534160
# 32116                  Low    704504320
# 36683                  Low    143843512
# 45217                 High    941831382
# 40343                  Low    688207719

# %%
categorical_data=df.select_dtypes(include='object')
numerical_data=df.select_dtypes(exclude='object')

# %% [markdown]
# ### univarate analysis to categorical data

# %%
plt.style.use('ggplot')
for cat in categorical_data:
    plt.figure(figsize=(9,5))
    val=categorical_data[cat].value_counts()
    sns.barplot(x=val.index,y=val.values,palette='dark')
    plt.title(f'Count OF {cat}')
    for index,value in enumerate (val.values):
        plt.text(index,value, str(value),va='bottom',ha='center')

# %% [markdown]
# ### Distribution the numerical data

# %%
for i in numerical_data:
    plt.figure(figsize=(9,5))
    plt.title(f'Distribution of {i}')
    sns.kdeplot(numerical_data[i],fill=True,color='b')

# %% [markdown]
# ### Distribution data and outliers using boxplot

# %%
for i in numerical_data:
    plt.figure(figsize=(9,5))
    plt.title(f'Distribution of {i}')
    sns.boxplot(numerical_data[i],color='b',orient='h')

# %%
df.describe()
# Out:
#                Year  Engine_Size_L     Mileage_KM      Price_USD  \
# count  50000.000000   50000.000000   50000.000000   50000.000000
# mean    2017.015700       3.247180  100307.203140   75034.600900
# std        4.324459       1.009078   57941.509344   25998.248882
# min     2010.000000       1.500000       3.000000   30000.000000
# 25%     2013.000000       2.400000   50178.000000   52434.750000
# 50%     2017.000000       3.200000  100388.500000   75011.500000
# 75%     2021.000000       4.100000  150630.250000   97628.250000
# max     2024.000000       5.000000  199996.000000  119998.000000
#
#        Sales_Volume   Total price
# count  50000.000000  5.000000e+04
# mean    5067.514680  3.802449e+08
# std     2856.767125  2.623406e+08
# min      100.000000  3.410472e+06
# 25%     2588.000000  1.689871e+08
# 50%     5087.000000  3.318010e+08
# 75%     7537.250000  5.486494e+08
# max     9999.000000  1.194346e+09

# %% [markdown]
# ### calculate outliers with maths

# %%
values = ['Price_USD', 'Sales_Volume','Total price']

for i in values:
    q1 = df[i].quantile(0.25)
    q3 = df[i].quantile(0.75)
    IQR = q3 - q1

    lower_bound = q1 - 1.5 * IQR
    upper_bound = q3 + 1.5 * IQR

    outliers = df[(df[i] < lower_bound) | (df[i] > upper_bound)]

    if outliers.empty:
        print(f'✅ No outliers found in {i}')
    else:
        print(f'⚠️ Found {len(outliers)} outliers in {i}')
        print(outliers[i].head())
# Out:
# ✅ No outliers found in Price_USD
# ✅ No outliers found in Sales_Volume
# ⚠️ Found 167 outliers in Total price
# 154    1154361520
# 238    1124709120
# 277    1151740800
# 726    1133161246
# 938    1155274407
# Name: Total price, dtype: int64

# %% [markdown]
# ### Analysis each categorical data column with Total Price

# %%
for i in categorical_data:
    group=df.groupby(i)['Total price'].sum().sort_values(ascending=False)
    plt.figure(figsize=(11,5))
    sns.barplot(x=group.values,y=group.index)
    plt.title(f'Total price BY {i}')
    for index,value in enumerate(group.values):
        plt.text(value,index,str(value),va='center',ha='left')

# %% [markdown]
# ### Total Price BY Year

# %%
grouped = df.groupby('Year')['Total price'].sum().reset_index()

plt.figure(figsize=(9,5))
sns.lineplot(data=grouped, x='Year', y='Total price', marker='o', linewidth=2)

plt.title('Total Money by Year', fontsize=14)
plt.xlabel('Year', fontsize=12)
plt.ylabel('Total Money', fontsize=12)
plt.grid(True)
plt.show()

# %% [markdown]
# ### Sales_Volume BY Sales_Classification

# %%
grouped = df.groupby('Sales_Classification')['Sales_Volume'].sum()
plt.pie(grouped.values,labels=group.index,autopct='%0.2f%%',shadow=True,explode=[0,0.05],startangle=10)
plt.title('Sales_Volume BY Sales_Classification')
plt.legend()
plt.show()
grouped
# Out:
# Sales_Classification
# High    129552829
# Low     123822905
# Name: Sales_Volume, dtype: int64

# %% [markdown]
# ### Analysis of the car Model with each Categorical data columns BY Total Price

# %%
from IPython.display import display

names = ['Region','Color','Fuel_Type','Transmission']

for i in names:
    d = pd.crosstab(df['Model'], df[i], values=df['Total price'], aggfunc='sum')
    d = d.round(2)
    print(f"\n===== Crosstab: Total Price by Model and {i} =====")
    display(d)
# Out:
# ===== Crosstab: Total Price by Model and Region =====
# Region          Africa          Asia        Europe   Middle East  \
# Model
# 3 Series  300107613560  302685161456  304196796025  290908487374
# 5 Series  306136833319  291989135417  291699397601  280945142628
# 1        i8  2013  North America    Red    Hybrid    Automatic            1.6
# 2  5 Series  2022  North America   Blue    Petrol    Automatic            4.5
# 3        X3  2024    Middle East   Blue    Petrol    Automatic            1.7
# 4  7 Series  2020  South America  Black    Diesel       Manual            2.1
#
#    Mileage_KM  Price_USD  Sales_Volume Sales_Classification  Total price
# 0      151748      98740          8300                 High    819542000
# 1      121671      79219          3428                  Low    271562732
# 2       10991     113265          6994                  Low    792175410
# 3       27255      60971          4047                  Low    246749637
# 4      122131      49898          3080                  Low    153685840

# %%
data=df.copy()

# %%
data.drop(['Sales_Volume','Total price'],axis=1,inplace=True)

# %% [markdown]
# ### SKlearn library

# %%
from sklearn.preprocessing import LabelEncoder,StandardScaler
from sklearn.model_selection import train_test_split,cross_val_score
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier

from sklearn.metrics import confusion_matrix,classification_report,accuracy_score

# %% [markdown]
# ### Encodeing

# %%
le=LabelEncoder()
data['Model']=le.fit_transform(data['Model'])
data['Region']=le.fit_transform(data['Region'])
data['Color']=le.fit_transform(data['Color'])
data['Fuel_Type']=le.fit_transform(data['Fuel_Type'])
data['Transmission']=le.fit_transform(data['Transmission'])
data['Sales_Classification']=le.fit_transform(data['Sales_Classification'])

# %%
data.head()
# Out:
#    Model  Year  Region  Color  Fuel_Type  Transmission  Engine_Size_L  \
# 0      1  2016       1      3          3             1            3.5
# 1     10  2013       4      3          2             0            1.6
# 2      1  2022       4      1          3             0            4.5
# 3      6  2024       3      1          3             0            1.7
# 4      2  2020       5      0          0             1            2.1
#
#    Mileage_KM  Price_USD  Sales_Classification
# 0      151748      98740                     0
# 1      121671      79219                     1
# 2       10991     113265                     1
# 3       27255      60971                     1
# 4      122131      49898                     1

# %%
data.shape
# Out:
# (50000, 10)

# %%
x=data.drop( 'Sales_Classification',axis=1)
y=data['Sales_Classification']

# %%
scale=StandardScaler()
X=scale.fit_transform(x)

# %% [markdown]
# ### cross valdation to evaluation the model

# %%
x_train,x_test,y_train,y_test=train_test_split(X,y,test_size=0.2,shuffle=True,random_state=42)

# %%
model_svm= SVC()
model_svm.fit(x_train,y_train)
# Out:
# SVC()

# %%
model_dt= DecisionTreeClassifier()
model_dt.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier()

# %%
model_rf= RandomForestClassifier()
model_rf.fit(x_train,y_train)
# Out:
# RandomForestClassifier()

# %%
y_pred_svm=model_svm.predict(x_test)
y_pred_dt=model_dt.predict(x_test)
y_pred_rf=model_rf.predict(x_test)

# %% [markdown]
# ### Model Accuracy Measurement

# %%
accuracy=accuracy_score(y_test,y_pred_svm)*100
print(f'Test Accuracy={accuracy} %')

train_accuracy = model_svm.score(x_train, y_train)
print(f"Training Accuracy: {train_accuracy * 100:.2f}%")
# Out:
# Test Accuracy=69.67999999999999 %
# Training Accuracy: 69.47%

# %%
accuracy=accuracy_score(y_test,y_pred_dt)*100
print(f'Test Accuracy={accuracy} %')

train_accuracy = model_dt.score(x_train, y_train)
print(f"Training Accuracy: {train_accuracy * 100:.2f}%")
# Out:
# Test Accuracy=57.3 %
# Training Accuracy: 100.00%

# %%
accuracy=accuracy_score(y_test,y_pred_rf)*100
print(f'Test Accuracy={accuracy} %')

train_accuracy = model_rf.score(x_train, y_train)
print(f"Training Accuracy: {train_accuracy * 100:.2f}%")
# Out:
# Test Accuracy=68.78 %
# Training Accuracy: 100.00%

# %%
cr=classification_report(y_test,y_pred)
print(f'===========Classification Report==============\n {cr}')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[37], line 1
# ----> 1 cr=classification_report(y_test,y_pred)
#       2 print(f'===========Classification Report==============\n {cr}')
#
# NameError: name 'y_pred' is not defined

# %%
cm=confusion_matrix(y_test,y_pred)
plt.figure(figsize=(10,5))
sns.heatmap(cm,annot=True,linewidths=0.2,fmt='1')
plt.xlabel('actual values')
plt.ylabel('prediction values')
plt.show()
